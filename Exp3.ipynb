# %%
from jupyterthemes import get_themes
import jupyterthemes as jt
from jupyterthemes.stylefx import set_nb_theme
set_nb_theme('monokai')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-d66017685ce9> in <module>()
# ----> 1 from jupyterthemes import get_themes
#       2 import jupyterthemes as jt
#       3 from jupyterthemes.stylefx import set_nb_theme
#       4 set_nb_theme('monokai')
#
# ModuleNotFoundError: No module named 'jupyterthemes'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
import numpy as np
import plotly.express as px
import pandas as pd
import plotly.graph_objects as go

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# Set 1
readings = pd.DataFrame()
readings['Current I (mA)'] = [104,132,160,188,215,241,267,293] # mA
readings['Current I (A)'] = readings['Current I (mA)']/1000 # A
readings['2Q (Volt)'] = [88.32,71.30,57.96,48.99,42.32,37.49,35.42,33.12] # Volts
readings['2Q (cm)'] = readings['2Q (Volt)']/18.4 # cm
readings['Q (cm)'] = readings['2Q (cm)']/2 # cm
readings['1/I (A^-1)'] = 1/readings['Current I (A)']
readings
# Out:
#    Current I (mA)  Current I (A)  2Q (Volt)  2Q (cm)   Q (cm)  1/I (A^-1)
# 0             104          0.104      88.32   4.8000  2.40000    9.615385
# 1             132          0.132      71.30   3.8750  1.93750    7.575758
# 2             160          0.160      57.96   3.1500  1.57500    6.250000
# 3             188          0.188      48.99   2.6625  1.33125    5.319149
# 4             215          0.215      42.32   2.3000  1.15000    4.651163
# 5             241          0.241      37.49   2.0375  1.01875    4.149378
# 6             267          0.267      35.42   1.9250  0.96250    3.745318
# 7             293          0.293      33.12   1.8000  0.90000    3.412969

# %%
fitted_polynomial_coeff = np.polyfit(readings['1/I (A^-1)'],readings['Q (cm)'],1)
fitted_polynomial = np.poly1d(fitted_polynomial_coeff)
fitted_data = pd.DataFrame()
fitted_data['x'] = np.linspace(3,10,num=1000)
fitted_data['y'] = fitted_polynomial(fitted_data['x'])

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=fitted_data['x'], y=fitted_data['y'],mode='lines',name='Fitted Curve'))
fig.add_trace(go.Scatter(x=readings['1/I (A^-1)'], y=readings['Q (cm)'],mode='markers',name='Observations'))
fig.update_layout(xaxis_title="1/I (A^-1) ------>",yaxis_title="Q (cm) ------>",height=600,title = "Exp3: 1/I vs Q Graph for Frequency = 13.02MHz")
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
slope = fitted_polynomial_coeff[0]
slope
# Out:
# 0.24897999658710204

# %% [markdown]
# # Set 2

# %%
readings = pd.DataFrame()
readings['Current I (mA)'] = [104,132,160,188,215,241,267,293] # mA
readings['Current I (A)'] = readings['Current I (mA)']/1000 # A
readings['2Q (Volt)'] = [97.39, 74.60, 62.99, 52.24,46.01, 41.06,37.195, 34.18] # Volts
readings['2Q (cm)'] = readings['2Q (Volt)']/17.2 # cm
readings['Q (cm)'] = readings['2Q (cm)']/2 # cm
readings['1/I (A^-1)'] = 1/readings['Current I (A)']
readings
# Out:
#    Current I (mA)  Current I (A)  2Q (Volt)   2Q (cm)    Q (cm)  1/I (A^-1)
# 0             104          0.104     97.390  5.662209  2.831105    9.615385
# 1             132          0.132     74.600  4.337209  2.168605    7.575758
# 2             160          0.160     62.990  3.662209  1.831105    6.250000
# 3             188          0.188     52.240  3.037209  1.518605    5.319149
# 4             215          0.215     46.010  2.675000  1.337500    4.651163
# 5             241          0.241     41.060  2.387209  1.193605    4.149378
# 6             267          0.267     37.195  2.162500  1.081250    3.745318
# 7             293          0.293     34.180  1.987209  0.993605    3.412969

# %%
fitted_polynomial_coeff = np.polyfit(readings['1/I (A^-1)'],readings['Q (cm)'],1)
fitted_polynomial = np.poly1d(fitted_polynomial_coeff)
fitted_data = pd.DataFrame()
fitted_data['x'] = np.linspace(3,10,num=1000)
fitted_data['y'] = fitted_polynomial(fitted_data['x'])

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=fitted_data['x'], y=fitted_data['y'],mode='lines',name='Fitted Curve'))
fig.add_trace(go.Scatter(x=readings['1/I (A^-1)'], y=readings['Q (cm)'],mode='markers',name='Observations'))
fig.update_layout(xaxis_title="1/I (A^-1) ------>",yaxis_title="Q (cm) ------>",height=600,title = "Exp3: 1/I vs Q Graph for Frequency = 14.07 MHz")
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
slope = fitted_polynomial_coeff[0]
slope
# Out:
# 0.2950193421123285

# %% [markdown]
# # Set 3

# %%
readings = pd.DataFrame()
readings['Current I (mA)'] = [104,132,160,188,215,241] # mA
readings['Current I (A)'] = readings['Current I (mA)']/1000 # A
readings['2Q (Volt)'] = [107.28,84.71,69.66,59.125,50.74,44.93] # Volts
readings['2Q (cm)'] = readings['2Q (Volt)']/17.2 # cm
readings['Q (cm)'] = readings['2Q (cm)']/2 # cm
readings['1/I (A^-1)'] = 1/readings['Current I (A)']
readings
# Out:
#    Current I (mA)  Current I (A)  2Q (Volt)   2Q (cm)    Q (cm)  1/I (A^-1)
# 0             104          0.104    107.280  6.237209  3.118605    9.615385
# 1             132          0.132     84.710  4.925000  2.462500    7.575758
# 2             160          0.160     69.660  4.050000  2.025000    6.250000
# 3             188          0.188     59.125  3.437500  1.718750    5.319149
# 4             215          0.215     50.740  2.950000  1.475000    4.651163
# 5             241          0.241     44.930  2.612209  1.306105    4.149378

# %%
fitted_polynomial_coeff = np.polyfit(readings['1/I (A^-1)'],readings['Q (cm)'],1)
fitted_polynomial = np.poly1d(fitted_polynomial_coeff)
fitted_data = pd.DataFrame()
fitted_data['x'] = np.linspace(3,10,num=1000)
fitted_data['y'] = fitted_polynomial(fitted_data['x'])

# Create traces
fig = go.Figure()
fig.add_trace(go.Scatter(x=fitted_data['x'], y=fitted_data['y'],mode='lines',name='Fitted Curve'))
fig.add_trace(go.Scatter(x=readings['1/I (A^-1)'], y=readings['Q (cm)'],mode='markers',name='Observations'))
fig.update_layout(xaxis_title="1/I (A^-1) ------>",yaxis_title="Q (cm) ------>",height=600,title = "Exp3: 1/I vs Q Graph for Frequency = 15.49 MHz")
fig.update_layout(legend=dict(
    yanchor="top",
    y=0.99,
    xanchor="left",
    x=0.01
))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
slope = fitted_polynomial_coeff[0]
slope
# Out:
# 0.33154975747242876
